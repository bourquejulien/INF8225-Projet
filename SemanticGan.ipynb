# %%
# !git clone https://github.com/bourquejulien/INF8225-Projet.git
# Out:
# Cloning into 'INF8225-Projet'...
# remote: Enumerating objects: 153, done.
# remote: Counting objects: 100% (153/153), done.
# remote: Compressing objects: 100% (132/132), done.
# remote: Total 153 (delta 29), reused 139 (delta 18), pack-reused 0
# Receiving objects: 100% (153/153), 3.88 MiB | 9.13 MiB/s, done.
# Resolving deltas: 100% (29/29), done.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd INF8225-Projet/SemanticGAN
! git pull
# !pip install -r requirements.txt > /dev/null
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: 'INF8225-Projet/SemanticGAN'
# /content/INF8225-Projet/INF8225-Projet/SemanticGAN
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), 346 bytes | 346.00 KiB/s, done.
# From https://github.com/bourquejulien/INF8225-Projet
#    e3e71a8..4c88fc8  master     -> origin/master
# Updating e3e71a8..4c88fc8
# Fast-forward
#  SemanticGAN/updater.py | 3 ---
#  1 file changed, 3 deletions(-)

# %%
# !./01-setup.sh
! mkdir -p /content/drive/MyDrive/Snapshots
# !ln -s /content/drive/MyDrive/Snapshots snapshot

# %%
# !./02-train.py
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#     2.9823 iters/sec. Estimated time to finish: 8:01:57.958958.
#      total [######............................................] 13.76%
# this epoch [###################...............................] 39.89%
#      13760 iter, 9 epoch / 100000 iterations
#     2.9821 iters/sec. Estimated time to finish: 8:01:58.881616.
#      total [######............................................] 13.76%
# this epoch [###################...............................] 39.96%
#      13761 iter, 9 epoch / 100000 iterations
#     2.9875 iters/sec. Estimated time to finish: 8:01:06.203846.
#      total [######............................................] 13.76%
# this epoch [####################..............................] 40.03%
#      13762 iter, 9 epoch / 100000 iterations
#     2.9872 iters/sec. Estimated time to finish: 8:01:08.770264.
#      total [######............................................] 13.76%
# ...

# %%
# !./03-inference.py -w snapshot/gen_iter_10000.npz  -i 2007_000170.jpg
# Out:
# load initmodel..
# /content/INF8225-Projet/INF8225-Projet/SemanticGAN/2007_000170.jpg:
# /content/INF8225-Projet/INF8225-Projet/SemanticGAN/./03-inference.py:40: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(img_file, mode='RGB')
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.10/dist-packages/skimage/measure/__init__.py", line 6, in <module>
#     from ._polygon import approximate_polygon, subdivide_polygon
#   File "/usr/local/lib/python3.10/dist-packages/skimage/measure/_polygon.py", line 2, in <module>
# ...
